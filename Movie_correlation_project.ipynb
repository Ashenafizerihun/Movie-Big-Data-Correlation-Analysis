# %%
#import libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 8)

#Read date
file_id = "18LgIi9aCQDD5ZlGLlEIwJoeKYfDw_XFG"
direct_link = f"https://drive.google.com/uc?id={file_id}"
df = pd.read_csv(direct_link)

# %%
#Drope some columns
df.drop(['index','homepage','id','keywords','original_language','spoken_languages','tagline','cast','crew','director','original_title'],axis=1,inplace=True)

# %%
pd.set_option('display.max_rows', 10)  # Display only 10 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4775 non-null   object
#  2   overview              4800 non-null   object
#  3   popularity            4803 non-null   float64
#  4   production_companies  4803 non-null   object
#  5   production_countries  4803 non-null   object
#  6   release_date          4802 non-null   object
#  7   revenue               4803 non-null   int64
#  8   runtime               4801 non-null   float64
#  9   status                4803 non-null   object
#  10  title                 4803 non-null   object
#  11  vote_average          4803 non-null   float64
#  12  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 487.9+ KB

# %%
#Drop null runtime value rows
df.dropna(subset=['runtime'], inplace=True)
df['runtime'] = df['runtime'].astype('int64')

# %%
df
# Out:
#          budget                                    genres  \
# 0     237000000  Action Adventure Fantasy Science Fiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000          Action Adventure Science Fiction
# ...         ...                                       ...
# 4798     220000                     Action Crime Thriller
# 4799       9000                            Comedy Romance
# 4800          0             Comedy Drama Romance TV Movie
# 4801          0                                       NaN
# 4802          0                               Documentary
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# ...

# %%
#Sort the dataframe by revenue column in descending order
df.sort_values(by=['revenue'],inplace=True,ascending=False)

# %%
df
# Out:
#          budget                                     genres  \
# 0     237000000   Action Adventure Fantasy Science Fiction
# 25    200000000                     Drama Romance Thriller
# 16    220000000           Science Fiction Action Adventure
# 28    150000000  Action Adventure Science Fiction Thriller
# 44    190000000                                     Action
# ...         ...                                        ...
# 3201    9000000                              Drama Romance
# 3200          0                              Drama Romance
# 3199          0               Thriller Mystery Crime Drama
# 3197    6500000                    Crime Drama History War
# 4802          0                                Documentary
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 25    84 years later, a 101-year-old woman named Ros...  100.025899
# ...

# %%
#Drop duplicates throughout the dataframe
df.drop_duplicates()
# Out:
#          budget                                     genres  \
# 0     237000000   Action Adventure Fantasy Science Fiction
# 25    200000000                     Drama Romance Thriller
# 16    220000000           Science Fiction Action Adventure
# 28    150000000  Action Adventure Science Fiction Thriller
# 44    190000000                                     Action
# ...         ...                                        ...
# 3201    9000000                              Drama Romance
# 3200          0                              Drama Romance
# 3199          0               Thriller Mystery Crime Drama
# 3197    6500000                    Crime Drama History War
# 4802          0                                Documentary
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 25    84 years later, a 101-year-old woman named Ros...  100.025899
# ...

# %%
# Scatter plot of budget Vs revenue
plt.scatter(df['budget'],df['revenue'])
plt.title('Budget Vs revunue')
plt.xlabel('budget')
plt.ylabel('revenue')
# Out:
# Text(0, 0.5, 'revenue')

# %%
# Budget Vs Revenue regression plot
sns.regplot(x='budget',y='revenue',data=df,scatter_kws={'color':'red'},line_kws={'color':'black'})
# Out:
# <Axes: xlabel='budget', ylabel='revenue'>

# %%
# corelation between numeric columns
df.corr(numeric_only=True)
# Out:
#                 budget  popularity   revenue   runtime  vote_average  \
# budget        1.000000    0.505346  0.730798  0.269851      0.092728
# popularity    0.505346    1.000000  0.644677  0.225502      0.274171
# revenue       0.730798    0.644677  1.000000  0.251093      0.197286
# runtime       0.269851    0.225502  0.251093  1.000000      0.375046
# vote_average  0.092728    0.274171  0.197286  0.375046      1.000000
# vote_count    0.593135    0.778098  0.781462  0.271944      0.313423
#
#               vote_count
# budget          0.593135
# popularity      0.778098
# revenue         0.781462
# runtime         0.271944
# vote_average    0.313423
# vote_count      1.000000

# %%
# heatmap between movie variables
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap(correlation_matrix,annot=True)
plt.title('Heatmap')
# Out:
# Text(0.5, 1.0, 'Heatmap')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4801 entries, 0 to 4802
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4801 non-null   int64
#  1   genres                4773 non-null   object
#  2   overview              4800 non-null   object
#  3   popularity            4801 non-null   float64
#  4   production_companies  4801 non-null   object
#  5   production_countries  4801 non-null   object
#  6   release_date          4800 non-null   object
#  7   revenue               4801 non-null   int64
#  8   runtime               4801 non-null   int64
#  9   status                4801 non-null   object
#  10  title                 4801 non-null   object
#  11  vote_average          4801 non-null   float64
#  12  vote_count            4801 non-null   int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 654.1+ KB

# %%
# Convert object columns to 'category' and numerize it
df_numerized = df.copy()
for df_column in df_numerized.columns:
    if df_numerized[df_column].dtype == 'object':  # Check if the column is of type 'object'
        df_numerized[df_column] = df_numerized[df_column].astype('category')  # Convert to category
        df_numerized[df_column] = df_numerized[df_column].cat.codes
df = df_numerized
df
# Out:
#          budget  genres  overview  popularity  production_companies  \
# 0     237000000      59      2524  150.437577                  1391
# 25    200000000     740        48  100.025899                  2294
# 16    220000000    1025      4564  144.448633                  2223
# 28    150000000      73      4230  418.708552                  3392
# 44    190000000       0      1798  102.322217                  3313
# ...         ...     ...       ...         ...                   ...
# 3201    9000000     730      1005    4.799022                  3407
# 3200          0     730      3698    2.351706                  1117
# 3199          0    1128      2688    7.247023                  2488
# 3197    6500000     566      1896    7.028946                   760
# 4802          0     596      1994    1.929883                  3694
#
#       production_countries  release_date     revenue  runtime  status  title  \
# ...

# %%
# heatmap between movie variables
correlation_matrix = df_numerized.corr(numeric_only=True)
sns.heatmap(correlation_matrix,annot=True)
plt.title('Heatmap')
# Out:
# Text(0.5, 1.0, 'Heatmap')

# %%
# coorelation between movie variables unstacked
correlation_matrix = df.corr()
correlation_matrix = correlation_matrix.unstack()

with pd.option_context('display.max_rows', None):
    print(correlation_matrix)
# Out:
# budget                budget                  1.000000
#                       genres                 -0.207818
#                       overview                0.067885
#                       popularity              0.505346
#                       production_companies    0.180305
#                       production_countries    0.078058
#                       release_date            0.142155
#                       revenue                 0.730798
#                       runtime                 0.269851
#                       status                 -0.007763
#                       title                   0.034584
#                       vote_average            0.092728
#                       vote_count              0.593135
# genres                budget                 -0.207818
#                       genres                  1.000000
#                       overview               -0.057263
#                       popularity             -0.062758
# ...

# %%
# Vote_count budget and pupularity have a higher correlation with the revenue
